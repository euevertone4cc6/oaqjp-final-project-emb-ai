# %% [markdown]
# <a href="https://colab.research.google.com/github/euevertone4cc6/oaqjp-final-project-emb-ai/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ferramentas para Ciência de Dados

# %%
## Introdução
# Este notebook apresenta algumas das principais ferramentas, linguagens e bibliotecas utilizadas em Ciência de Dados.

# %%
print("As linguagens mais populares para Ciência de Dados são:\n- Python\n- R\n- SQL\n- Julia\n- Scala")
# Out:
# As linguagens mais populares para Ciência de Dados são:
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# print("## Bibliotecas de Ciência de Dados")
# print("Algumas bibliotecas essenciais:")
# print("- Pandas (Python)")
# print("- NumPy (Python)")
# print("- Matplotlib/Seaborn (Visualização)")
# print("- Scikit-learn (Machine Learning)")
# print("- TensorFlow/PyTorch (Deep Learning)")
# print("- Caret (R)")
# print("- dplyr (R)")

# %%
print("## Bibliotecas de Ciência de Dados")
print("Algumas bibliotecas essenciais:")
print("- Pandas (Python)")
print("- NumPy (Python)")
print("- Matplotlib/Seaborn (Visualização)")
print("- Scikit-learn (Machine Learning)")
print("- TensorFlow/PyTorch (Deep Learning)")
print("- Caret (R)")
print("- dplyr (R)")
# Out:
# ## Bibliotecas de Ciência de Dados
# Algumas bibliotecas essenciais:
# - Pandas (Python)
# - NumPy (Python)
# - Matplotlib/Seaborn (Visualização)
# - Scikit-learn (Machine Learning)
# - TensorFlow/PyTorch (Deep Learning)
# - Caret (R)
# - dplyr (R)

# %%
print("## Ferramentas de Ciência de Dados")
print("")
print("| Ferramenta          | Uso Principal                     |")
print("|---------------------|-----------------------------------|")
print("| Jupyter Notebook    | Análise interativa de dados       |")
print("| Google Colab        | Notebooks na nuvem                |")
print("| RStudio             | Análise estatística com R         |")
print("| VS Code             | Editor de código versátil         |")
print("| GitHub              | Versionamento e colaboração       |")
print("| Tableau             | Visualização de dados             |")
# Out:
# ## Ferramentas de Ciência de Dados
#
# | Ferramenta          | Uso Principal                     |
# |---------------------|-----------------------------------|
# | Jupyter Notebook    | Análise interativa de dados       |
# | Google Colab        | Notebooks na nuvem                |
# | RStudio             | Análise estatística com R         |
# | VS Code             | Editor de código versátil         |
# | GitHub              | Versionamento e colaboração       |
# | Tableau             | Visualização de dados             |

# %%
print("## Exemplos de Expressões Aritméticas")
print("A seguir, demonstraremos operações básicas como multiplicação e soma.")
# Out:
# ## Exemplos de Expressões Aritméticas
# A seguir, demonstraremos operações básicas como multiplicação e soma.

# %%
# Multiplicação e Soma
a = 5
b = 3
print("Multiplicação:", a * b)
print("Soma:", a + b)
# Out:
# Multiplicação: 15
# Soma: 8

# %%
# Conversão de Minutos para Horas
minutos = 150
horas = minutos / 60
print(f"{minutos} minutos equivalem a {horas:.2f} horas")
# Out:
# 150 minutos equivalem a 2.50 horas

# %%
print("## Objetivos")
print("- Apresentar ferramentas essenciais para Ciência de Dados.")
print("- Demonstrar operações básicas em Python.")
print("- Compartilhar conhecimento através do GitHub.")
# Out:
# ## Objetivos
# - Apresentar ferramentas essenciais para Ciência de Dados.
# - Demonstrar operações básicas em Python.
# - Compartilhar conhecimento através do GitHub.

# %%
print("## Autor")
print("**Everton RABAQUIM**")
# Out:
# ## Autor
# **Everton RABAQUIM**
